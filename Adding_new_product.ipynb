# %%
import json



Entry=True
while(Entry):
    fd=open('prodlist.json','r')
    r=fd.read()
    fd.close()
    record=json.loads(r)

    print("Press: 0  for Showing All Data.\n")
    print("Press: 1 for Add product.\n")
    print("Press: 2 for Update\n")
    print("Press: 3 for Delete.\n")
    print("Press: 4  for Exit.\n")
    x=int(input(""))
    if(x==0):
        print("******"*15)
        print("\tProduct_id\tProduct_name\tProduct_Quantity\tPrice")
        print("******"*15)
        for i in record.keys():
            print(f"\t{i}\t\t{record[i]['product_name']}\t\t{record[i]['product_quantity']}\t\t{record[i]['product_price']}\n")
    if(x==1):
        y=True
        while(y):
            found=False
            pro_id=input("Enter Product Id: ")
            for i in record.keys():
                if(i==pro_id):
                    print(f"product Id {pro_id} is already pressent\n")
                    print("Please Enter a new Id :")
                    found=True
            if(found):
                continue;
            else:
                pro_name=input("Enter Product Name:- ")
                pro_quantity=int(input("Enter Number of Quantity of product:- "))
                pro_price=int(input("Enter price of each product:- "))

                record[pro_id]={'product_name':pro_name,'product_quantity':pro_quantity,'product_price':pro_price}

                js = json.dumps(record)
                fd = open("prodlist.json",'w')
                fd.write(js)
                fd.close()
                print("******Your Product Add Success Fully******")
                y=False
    elif(x==2):
        y=True
        while(y):
            found=False
            pro_id=input("Enter Product Id: ")
            for i in record.keys():
                if(i==pro_id):
                    pro_name=input("Enter Product Name:- ")
                    pro_quantity=int(input("Enter Number of Quantity of product:- "))
                    pro_price=int(input("Enter price of each product:- "))
                    record[pro_id]={'product_name':pro_name,'product_quantity':pro_quantity,'product_price':pro_price}
                    js = json.dumps(record)
                    fd = open("prodlist.json",'w')
                    fd.write(js)
                    fd.close()
                    print("******Your Product Update Success Fully******")
                    found=True
                    y=False
            if(found):
                continue;
            else:
                print(f"product Id {pro_id} is Not pressent\n")
                print("Please Re-enter Product Id:")
    elif(x==3):
        y=True
        while(y):
            found=False
            pro_id=input("Enter Product Id: ")
            for i in record.keys():
                if(i==pro_id):
                    found=True
                    y=False
            if(found):
                del record[pro_id]
                js = json.dumps(record)
                fd = open("prodlist.json",'w')
                fd.write(js)
                fd.close()
                print("******Delete Success Fully******")
                continue;
            else:
                print(f"product Id {pro_id} is Not pressent\n")
                print("Please Re-enter Product Id:")
    elif(x==4):
        Entry=False
# Out:
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 0
# ******************************************************************************************
# 	Product_id	Product_name	Product_Quantity	Price
# ******************************************************************************************
# 	1		Calculator		33		250
#
# 	2		Highlight Pen		70		15
#
# 	3		Staplers		100		30
#
# 	4		Sticky Tapes		50		110
#
# 	5		Scissors		80		20
#
# 	6		Desk Tidy		80		70
#
# 	7		Pen Cups		60		35
#
# 	8		Note Holders		100		60
#
# 	9		Paper clip		200		5
#
# 	10		Waste Buckets		30		50
#
# 	11		RollerBall Pen		105		25
#
# 	12		Card Holder		90		22
#
# 	13		Register		70		60
#
# 	14		Tape Dispenser		65		40
#
# 	15		Gemotry Box		88		36
#
# 	16		Push-Pin		250		3
#
# 	17		Paper-Pin		300		4
#
# 	18		Rubber Stamp		60		50
#
# 	19		clip Board		55		28
#
# 	20		Paper Cutter		77		10
#
# 	21		Pen		150		10
#
# 	22		Pencil		100		5
#
# 	23		Color		40		55
#
# 	24		Glue		56		7
#
# 	25		Eraser		60		3
#
# 	26		Folder		250		5
#
# 	27		Fax		55		240
#
# 	28		Photocopy Paper A4		77		230
#
# 	29		Punching Machine		55		60
#
# 	30		Fevecool 10ml		55		13
#
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 1
# Enter Product Id: 10
# product Id 10 is already pressent
#
# Please Enter a new Id :
# Enter Product Id: 31
# Enter Product Name:- cake
# Enter Number of Quantity of product:- 10
# Enter price of each product:- 200
# ******Your Product Add Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 3
# Enter Product Id: 98
# product Id 98 is Not pressent
#
# Please Re-enter Product Id:
# Enter Product Id: 31
# ******Delete Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 1
# Enter Product Id: 31
# Enter Product Name:- cake
# Enter Number of Quantity of product:- 15
# Enter price of each product:- 350
# ******Your Product Add Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 3
# Enter Product Id: 31
# ******Delete Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 98
# product Id 98 is Not pressent
#
# Please Re-enter Product Id:
# Enter Product Id: 30
# Enter Product Name:- Fevecool 10ml
# Enter Number of Quantity of product:- 50
# Enter price of each product:- 14
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 4

# %%
import json

fd=open('prodlist.json','r')
r=fd.read()
record=json.loads(r)
print(len(record))
fd.close()
# Out:
# 23
